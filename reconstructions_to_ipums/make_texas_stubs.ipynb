# %%
import os
import pandas as pd
import maup
import geopandas as gp

import sys; sys.path.append("..") # Adds parent directory to python modules path.
from topdown_parsers import *

# %%
def modify_race(race):
    """
    """
    if race == "w":
        return 1
    elif race == "b":
        return 2
    elif race == "i":
        return 3
    elif race == "a":
        return 4
    elif race == "h":
        return 5
    else:
        return 6

def compute_pops_and_vaps(df, groupby_cols):
    # make bool columns for the counts
    df["race"] = df["race"].map(lambda race: modify_race(race))

    # sex
    df["male"] = df["sex"] == 0
    df["female"] = df["sex"] == 1

    # voting age
    df["VAP"] = df["age"] >= 18

    df = df.rename(columns={"ethn": "HISP"})

    # ethnicity vap
    df["HVAP"] = (df["HISP"] == 1) & (df["VAP"] == True)

    # race pops
    df["NH_WHITEPOP"] = (df["race"] == 1) &  (df["HISP"] != 1)
    df["NH_BLACKPOP"] = (df["race"] == 2) & (df["HISP"] != 1)
    df["NH_AMINPOP"] = (df["race"] == 3) & (df["HISP"] != 1)
    df["NH_ASIANPOP"] = (df["race"] == 4) & (df["HISP"] != 1)
    df["NH_HAWAIIANPOP"] = (df["race"] == 5) & (df["HISP"] != 1)
    df["NH_OTHERPOP"] = (df["race"] == 6) & (df["HISP"] != 1)

    # race vaps
    df["NH_WVAP"] = (df["race"] == 1) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_BVAP"] = (df["race"] == 2) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_AMINVAP"] = (df["race"] == 3) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_ASIANVAP"] = (df["race"] == 4) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_HAWAIIANVAP"] = (df["race"] == 5) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_OTHERVAP"] = (df["race"] == 6) & (df["VAP"] == True) & (df["HISP"] != 1)
    
    df["TOTPOP"] = 1

    df = df.drop(columns=["sex", "age", "GEOID", "race", "sol"])
    df = df.groupby(groupby_cols).sum().reset_index()
    
    return df

# %%
# do it for all of Texas
texas_df = read_and_process_reconstructed_csvs("./Reconstructed")
print("Computing pops and vaps")
texas_df = compute_pops_and_vaps(texas_df, ["state", "county"])
texas_df

# %%
# do dallas at the block level
dallas_df = read_and_process_reconstructed_csvs("./Reconstructed/Texas_Dallas County")
dallas_df = compute_pops_and_vaps(dallas_df, ["state", "county", "tract", "bg", "block"])
dallas_df

# %%
texas_df.to_csv("texas_reconstructions.csv", index=False)
dallas_df.to_csv("dallas_reconstructions.csv", index=False)

# %%
all_dirs = []
for root, dirs, files in os.walk("./Reconstructed"):
    for d in dirs:
        all_dirs.append(os.path.join(root, d))
        
for index, d in enumerate(sorted(all_dirs)):
    county_name = d[:-7].split("_")[1]
    print()
    print(county_name)
    print("County {} of {}".format(index, len(all_dirs)))
    convert_reconstructions_to_ipums(d, county_name + ".dat", break_size=1000)
# Out:
# Anderson
# County 0 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1604.
# Writing block 1000 of 1604.
#
# Andrews
# County 1 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 543.
#
# Angelina
# County 2 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1884.
# Writing block 1000 of 1884.
#
# Aransas
# County 3 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 800.
#
# Archer
# County 4 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 520.
#
# Armstrong
# County 5 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 235.
#
# Atascosa
# County 6 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1446.
# Writing block 1000 of 1446.
#
# Austin
# County 7 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1007.
# Writing block 1000 of 1007.
#
# Bailey
# County 8 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 465.
#
# Bandera
# County 9 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 863.
#
# Bastrop
# County 10 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1906.
# Writing block 1000 of 1906.
#
# Baylor
# County 11 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 336.
#
# Bee
# County 12 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1017.
# Writing block 1000 of 1017.
#
# Bell
# County 13 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 5328.
# Writing block 1000 of 5328.
# Writing block 2000 of 5328.
# Writing block 3000 of 5328.
# Writing block 4000 of 5328.
# Writing block 5000 of 5328.
#
# Bexar
# County 14 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 17739.
# Writing block 1000 of 17739.
# Writing block 2000 of 17739.
# Writing block 3000 of 17739.
# Writing block 4000 of 17739.
# Writing block 5000 of 17739.
# Writing block 6000 of 17739.
# Writing block 7000 of 17739.
# Writing block 8000 of 17739.
# Writing block 9000 of 17739.
# Writing block 10000 of 17739.
# Writing block 11000 of 17739.
# Writing block 12000 of 17739.
# Writing block 13000 of 17739.
# Writing block 14000 of 17739.
# Writing block 15000 of 17739.
# Writing block 16000 of 17739.
# Writing block 17000 of 17739.
#
# Blanco
# County 15 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 545.
#
# Borden
# County 16 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 98.
#
# Bosque
# County 17 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1273.
# Writing block 1000 of 1273.
#
# Bowie
# County 18 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2387.
# Writing block 1000 of 2387.
# Writing block 2000 of 2387.
#
# Brazoria
# County 19 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 4891.
# Writing block 1000 of 4891.
# Writing block 2000 of 4891.
# Writing block 3000 of 4891.
# Writing block 4000 of 4891.
#
# Brazos
# County 20 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2396.
# Writing block 1000 of 2396.
# Writing block 2000 of 2396.
#
# Brewster
# County 21 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 714.
#
# Briscoe
# County 22 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 223.
#
# Brooks
# County 23 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 314.
#
# Brown
# County 24 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1544.
# Writing block 1000 of 1544.
#
# Burleson
# County 25 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 789.
#
# Burnet
# County 26 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1623.
# Writing block 1000 of 1623.
#
# Caldwell
# County 27 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1188.
# Writing block 1000 of 1188.
#
# Calhoun
# County 28 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 805.
#
# Callahan
# County 29 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 677.
#
# Cameron
# County 30 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 6350.
# Writing block 1000 of 6350.
# Writing block 2000 of 6350.
# Writing block 3000 of 6350.
# Writing block 4000 of 6350.
# Writing block 5000 of 6350.
# Writing block 6000 of 6350.
#
# Camp
# County 31 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 494.
#
# Carson
# County 32 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 515.
#
# Cass
# County 33 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1430.
# Writing block 1000 of 1430.
#
# Castro
# County 34 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 617.
#
# Chambers
# County 35 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 698.
#
# Cherokee
# County 36 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1814.
# Writing block 1000 of 1814.
#
# Childress
# County 37 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 506.
#
# Clay
# County 38 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 779.
#
# Cochran
# County 39 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 293.
#
# Coke
# County 40 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 379.
# Coleman
# County 41 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1003.
# Writing block 1000 of 1003.
#
# Collin
# County 42 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 9604.
# Writing block 1000 of 9604.
# Writing block 2000 of 9604.
# Writing block 3000 of 9604.
# Writing block 4000 of 9604.
# Writing block 5000 of 9604.
# Writing block 6000 of 9604.
# Writing block 7000 of 9604.
# Writing block 8000 of 9604.
# Writing block 9000 of 9604.
#
# Collingsworth
# County 43 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 349.
#
# Colorado
# County 44 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1144.
# Writing block 1000 of 1144.
#
# Comal
# County 45 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2103.
# Writing block 1000 of 2103.
# Writing block 2000 of 2103.
#
# Comanche
# County 46 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 989.
#
# Concho
# County 47 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 308.
#
# Cooke
# County 48 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1503.
# Writing block 1000 of 1503.
#
# Coryell
# County 49 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1435.
# Writing block 1000 of 1435.
#
# Cottle
# County 50 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 236.
#
# Crane
# County 51 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 203.
#
# Crockett
# County 52 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 254.
#
# Crosby
# County 53 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 553.
#
# Culberson
# County 54 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 201.
#
# Dallam
# County 55 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 472.
#
# Dallas
# County 56 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 25677.
# Writing block 1000 of 25677.
# Writing block 2000 of 25677.
# Writing block 3000 of 25677.
# Writing block 4000 of 25677.
# Writing block 5000 of 25677.
# Writing block 6000 of 25677.
# Writing block 7000 of 25677.
# Writing block 8000 of 25677.
# Writing block 9000 of 25677.
# Writing block 10000 of 25677.
# Writing block 11000 of 25677.
# Writing block 12000 of 25677.
# Writing block 13000 of 25677.
# Writing block 14000 of 25677.
# Writing block 15000 of 25677.
# Writing block 16000 of 25677.
# Writing block 17000 of 25677.
# Writing block 18000 of 25677.
# Writing block 19000 of 25677.
# Writing block 20000 of 25677.
# Writing block 21000 of 25677.
# Writing block 22000 of 25677.
# Writing block 23000 of 25677.
# Writing block 24000 of 25677.
# Writing block 25000 of 25677.
#
# Dawson
# County 57 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 841.
#
# DeWitt
# County 58 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1196.
# Writing block 1000 of 1196.
#
# Deaf Smith
# County 59 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 745.
# Delta
# County 60 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 407.
#
# Denton
# County 61 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 8362.
# Writing block 1000 of 8362.
# Writing block 2000 of 8362.
# Writing block 3000 of 8362.
# Writing block 4000 of 8362.
# Writing block 5000 of 8362.
# Writing block 6000 of 8362.
# Writing block 7000 of 8362.
# Writing block 8000 of 8362.
#
# Dickens
# County 62 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 259.
#
# Dimmit
# County 63 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 588.
#
# Donley
# County 64 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 449.
#
# Duval
# County 65 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 683.
#
# Eastland
# County 66 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1315.
# Writing block 1000 of 1315.
#
# Ector
# County 67 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2899.
# Writing block 1000 of 2899.
# Writing block 2000 of 2899.
#
# Edwards
# County 68 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 239.
#
# El Paso
# County 69 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 9246.
# Writing block 1000 of 9246.
# Writing block 2000 of 9246.
# Writing block 3000 of 9246.
# Writing block 4000 of 9246.
# Writing block 5000 of 9246.
# Writing block 6000 of 9246.
# Writing block 7000 of 9246.
# Writing block 8000 of 9246.
# Writing block 9000 of 9246.
#
# Ellis
# County 70 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 3373.
# Writing block 1000 of 3373.
# Writing block 2000 of 3373.
# Writing block 3000 of 3373.
#
# Erath
# County 71 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1442.
# Writing block 1000 of 1442.
#
# Falls
# County 72 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1020.
# Writing block 1000 of 1020.
#
# Fannin
# County 73 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1576.
# Writing block 1000 of 1576.
#
# Fayette
# County 74 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1536.
# Writing block 1000 of 1536.
#
# Fisher
# County 75 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 520.
#
# Floyd
# County 76 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 606.
#
# Foard
# County 77 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 186.
#
# Fort Bend
# County 78 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 6200.
# Writing block 1000 of 6200.
# Writing block 2000 of 6200.
# Writing block 3000 of 6200.
# Writing block 4000 of 6200.
# Writing block 5000 of 6200.
# Writing block 6000 of 6200.
#
# Franklin
# County 79 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 503.
# Freestone
# County 80 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 962.
#
# Frio
# County 81 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 760.
#
# Gaines
# County 82 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 777.
#
# Galveston
# County 83 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 5798.
# Writing block 1000 of 5798.
# Writing block 2000 of 5798.
# Writing block 3000 of 5798.
# Writing block 4000 of 5798.
# Writing block 5000 of 5798.
#
# Garza
# County 84 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 314.
#
# Gillespie
# County 85 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 904.
#
# Glasscock
# County 86 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 176.
#
# Goliad
# County 87 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 302.
#
# Gonzales
# County 88 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1036.
# Writing block 1000 of 1036.
#
# Gray
# County 89 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1011.
# Writing block 1000 of 1011.
#
# Grayson
# County 90 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 3860.
# Writing block 1000 of 3860.
# Writing block 2000 of 3860.
# Writing block 3000 of 3860.
#
# Gregg
# County 91 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2734.
# Writing block 1000 of 2734.
# Writing block 2000 of 2734.
#
# Grimes
# County 92 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 942.
#
# Guadalupe
# County 93 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2073.
# Writing block 1000 of 2073.
# Writing block 2000 of 2073.
#
# Hale
# County 94 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1633.
# Writing block 1000 of 1633.
#
# Hall
# County 95 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 341.
#
# Hamilton
# County 96 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 656.
#
# Hansford
# County 97 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 360.
#
# Hardeman
# County 98 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 452.
#
# Hardin
# County 99 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1396.
# Writing block 1000 of 1396.
#
# Harris
# County 100 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 39294.
# Writing block 1000 of 39294.
# Writing block 2000 of 39294.
# Writing block 3000 of 39294.
# Writing block 4000 of 39294.
# Writing block 5000 of 39294.
# Writing block 6000 of 39294.
# Writing block 7000 of 39294.
# Writing block 8000 of 39294.
# Writing block 9000 of 39294.
# Writing block 10000 of 39294.
# Writing block 11000 of 39294.
# Writing block 12000 of 39294.
# Writing block 13000 of 39294.
# Writing block 14000 of 39294.
# Writing block 15000 of 39294.
# Writing block 16000 of 39294.
# Writing block 17000 of 39294.
# Writing block 18000 of 39294.
# Writing block 19000 of 39294.
# Writing block 20000 of 39294.
# Writing block 21000 of 39294.
# Writing block 22000 of 39294.
# Writing block 23000 of 39294.
# Writing block 24000 of 39294.
# Writing block 25000 of 39294.
# Writing block 26000 of 39294.
# Writing block 27000 of 39294.
# Writing block 28000 of 39294.
# Writing block 29000 of 39294.
# Writing block 30000 of 39294.
# Writing block 31000 of 39294.
# Writing block 32000 of 39294.
# Writing block 33000 of 39294.
# Writing block 34000 of 39294.
# Writing block 35000 of 39294.
# Writing block 36000 of 39294.
# Writing block 37000 of 39294.
# Writing block 38000 of 39294.
# Writing block 39000 of 39294.
#
# Harrison
# County 101 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2015.
# Writing block 1000 of 2015.
# Writing block 2000 of 2015.
#
# Hartley
# County 102 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 281.
#
# Haskell
# County 103 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 593.
#
# Hays
# County 104 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2082.
# Writing block 1000 of 2082.
# Writing block 2000 of 2082.
#
# Hemphill
# County 105 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 300.
#
# Henderson
# County 106 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2631.
# Writing block 1000 of 2631.
# Writing block 2000 of 2631.
#
# Hidalgo
# County 107 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 10366.
# Writing block 1000 of 10366.
# Writing block 2000 of 10366.
# Writing block 3000 of 10366.
# Writing block 4000 of 10366.
# Writing block 5000 of 10366.
# Writing block 6000 of 10366.
# Writing block 7000 of 10366.
# Writing block 8000 of 10366.
# Writing block 9000 of 10366.
# Writing block 10000 of 10366.
#
# Hill
# County 108 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1858.
# Writing block 1000 of 1858.
#
# Hockley
# County 109 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1264.
# Writing block 1000 of 1264.
#
# Hood
# County 110 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1361.
# Writing block 1000 of 1361.
#
# Hopkins
# County 111 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1195.
# Writing block 1000 of 1195.
#
# Houston
# County 112 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 958.
#
# Howard
# County 113 of 254
# Reading files...
# ...
# Writing block 0 of 139.
#
# Stonewall
# County 216 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 205.
#
# Sutton
# County 217 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 261.
#
# Swisher
# County 218 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 651.
#
# Tarrant
# County 219 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 22203.
# Writing block 1000 of 22203.
# Writing block 2000 of 22203.
# Writing block 3000 of 22203.
# Writing block 4000 of 22203.
# Writing block 5000 of 22203.
# Writing block 6000 of 22203.
# Writing block 7000 of 22203.
# Writing block 8000 of 22203.
# Writing block 9000 of 22203.
# Writing block 10000 of 22203.
# Writing block 11000 of 22203.
# Writing block 12000 of 22203.
# Writing block 13000 of 22203.
# Writing block 14000 of 22203.
# Writing block 15000 of 22203.
# Writing block 16000 of 22203.
# Writing block 17000 of 22203.
# Writing block 18000 of 22203.
# Writing block 19000 of 22203.
# Writing block 20000 of 22203.
# Writing block 21000 of 22203.
# Writing block 22000 of 22203.
#
# Taylor
# County 220 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 3022.
# Writing block 1000 of 3022.
# Writing block 2000 of 3022.
# Writing block 3000 of 3022.
#
# Terrell
# County 221 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 87.
# Terry
# County 222 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 700.
#
# Throckmorton
# County 223 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 199.
#
# Titus
# County 224 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 836.
#
# Tom Green
# County 225 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2941.
# Writing block 1000 of 2941.
# Writing block 2000 of 2941.
#
# Travis
# County 226 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 10721.
# Writing block 1000 of 10721.
# Writing block 2000 of 10721.
# Writing block 3000 of 10721.
# Writing block 4000 of 10721.
# Writing block 5000 of 10721.
# Writing block 6000 of 10721.
# Writing block 7000 of 10721.
# Writing block 8000 of 10721.
# Writing block 9000 of 10721.
# Writing block 10000 of 10721.
#
# Trinity
# County 227 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 698.
#
# Tyler
# County 228 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 909.
#
# Upshur
# County 229 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1414.
# Writing block 1000 of 1414.
#
# Upton
# County 230 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 302.
#
# Uvalde
# County 231 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1002.
# Writing block 1000 of 1002.
#
# Val Verde
# County 232 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1477.
# Writing block 1000 of 1477.
#
# Van Zandt
# County 233 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1708.
# Writing block 1000 of 1708.
#
# Victoria
# County 234 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1885.
# Writing block 1000 of 1885.
#
# Walker
# County 235 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1070.
# Writing block 1000 of 1070.
#
# Waller
# County 236 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1198.
# Writing block 1000 of 1198.
#
# Ward
# County 237 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 698.
#
# Washington
# County 238 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1214.
# Writing block 1000 of 1214.
#
# Webb
# County 239 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 3475.
# Writing block 1000 of 3475.
# Writing block 2000 of 3475.
# Writing block 3000 of 3475.
#
# Wharton
# County 240 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1724.
# Writing block 1000 of 1724.
#
# Wheeler
# County 241 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 550.
#
# Wichita
# County 242 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 2769.
# Writing block 1000 of 2769.
# Writing block 2000 of 2769.
#
# Wilbarger
# County 243 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 717.
#
# Willacy
# County 244 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 755.
#
# Williamson
# County 245 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 5833.
# Writing block 1000 of 5833.
# Writing block 2000 of 5833.
# Writing block 3000 of 5833.
# Writing block 4000 of 5833.
# Writing block 5000 of 5833.
#
# Wilson
# County 246 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1074.
# Writing block 1000 of 1074.
#
# Winkler
# County 247 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 348.
#
# Wise
# County 248 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1979.
# Writing block 1000 of 1979.
#
# Wood
# County 249 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 1668.
# Writing block 1000 of 1668.
#
# Yoakum
# County 250 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 466.
#
# Young
# County 251 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 859.
#
# Zapata
# County 252 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 641.
#
# Zavala
# County 253 of 254
# Reading files...
# Duplicating rows... (based on reconstructed solutions)
# Processing Geo IDs
# Splitting into geounits...
# Cleaning up the geounits...
# Converting to fips codes and paddings them up...
# Building Enumdist column
# Done with reading and preparing data.
# Grouping the data at a block level...
# Finished grouping the data.
# Writing block 0 of 501.
