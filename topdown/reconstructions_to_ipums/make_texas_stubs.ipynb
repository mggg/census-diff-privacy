# %%
import os
import pandas as pd
import maup
import geopandas as gp

import sys; sys.path.append("..") # Adds parent directory to python modules path.
from topdown_parsers import *

# %%
# def modify_race(race):
#     """
#     """
#     if race == "w":
#         return 1
#     elif race == "b":
#         return 2
#     elif race == "i":
#         return 3
#     elif race == "a":
#         return 4
#     elif race == "h":
#         return 5
#     else:
#         return 6

def compute_pops_and_vaps(df, groupby_cols):
    # make bool columns for the counts
    df["race"] = df["race"].map(lambda race: modify_race(race))

    # sex
    df["male"] = df["sex"] == 0
    df["female"] = df["sex"] == 1

    # voting age
    df["VAP"] = df["age"] >= 18

    df = df.rename(columns={"ethn": "HISP"})

    # ethnicity vap
    df["HVAP"] = (df["HISP"] == 1) & (df["VAP"] == True)

    # race pops
    df["NH_WHITEPOP"] = (df["race"] == 1) &  (df["HISP"] != 1)
    df["NH_BLACKPOP"] = (df["race"] == 2) & (df["HISP"] != 1)
    df["NH_AMINPOP"] = (df["race"] == 3) & (df["HISP"] != 1)
    df["NH_ASIANPOP"] = (df["race"] == 4) & (df["HISP"] != 1)
    df["NH_HAWAIIANPOP"] = (df["race"] == 5) & (df["HISP"] != 1)
    df["NH_OTHERPOP"] = (df["race"] == 6) & (df["HISP"] != 1)

    # race vaps
    df["NH_WVAP"] = (df["race"] == 1) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_BVAP"] = (df["race"] == 2) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_AMINVAP"] = (df["race"] == 3) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_ASIANVAP"] = (df["race"] == 4) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_HAWAIIANVAP"] = (df["race"] == 5) & (df["VAP"] == True) & (df["HISP"] != 1)
    df["NH_OTHERVAP"] = (df["race"] == 6) & (df["VAP"] == True) & (df["HISP"] != 1)
    
    df["TOTPOP"] = 1

    df = df.drop(columns=["sex", "age", "GEOID", "race", "sol"])
    df = df.groupby(groupby_cols).sum().reset_index()
    
    return df

# %%
# do it for all of Texas
texas_df = read_and_process_reconstructed_csvs("./Reconstructed")
print("Computing pops and vaps")
texas_df = compute_pops_and_vaps(texas_df, ["state", "county"])
texas_df

# %%
# do dallas at the block level
dallas_df = read_and_process_reconstructed_csvs("./Reconstructed/Texas_Dallas County")
dallas_df = compute_pops_and_vaps(dallas_df, ["state", "county", "tract", "bg", "block"])
dallas_df

# %%
texas_df.to_csv("texas_reconstructions.csv", index=False)
dallas_df.to_csv("dallas_reconstructions.csv", index=False)

# %%
# put all of the county in the same enumdist (except for Dallas)
all_dirs = []
for root, dirs, files in os.walk("./new_Reconstructed"):
    for d in dirs:
        all_dirs.append(os.path.join(root, d))
        
for index, d in enumerate(sorted(all_dirs)):
    county_name = d[:-7].split("_")[2]
    print()
    print(county_name)
    print("County {} of {}".format(index, len(all_dirs)))
#     if county_name in ["Bell", "Galveston", "Nueces", "Brazoria", "Cameron"]:
#         convert_reconstructions_to_ipums(d, county_name + ".dat", break_size=1000)
    if county_name == "Dallas":
        convert_reconstructions_to_ipums_same_block(d, county_name + ".dat")
# Out:
# Anderson
# County 0 of 254
#
# Andrews
# County 1 of 254
#
# Angelina
# County 2 of 254
#
# Aransas
# County 3 of 254
#
# Archer
# County 4 of 254
#
# Armstrong
# County 5 of 254
#
# Atascosa
# County 6 of 254
#
# Austin
# County 7 of 254
#
# Bailey
# County 8 of 254
#
# Bandera
# County 9 of 254
#
# Bastrop
# County 10 of 254
#
# Baylor
# County 11 of 254
#
# Bee
# County 12 of 254
#
# Bell
# County 13 of 254
#
# Bexar
# County 14 of 254
#
# Blanco
# County 15 of 254
#
# Borden
# County 16 of 254
#
# Bosque
# County 17 of 254
#
# Bowie
# County 18 of 254
#
# Brazoria
# County 19 of 254
#
# Brazos
# County 20 of 254
#
# Brewster
# County 21 of 254
#
# Briscoe
# County 22 of 254
#
# Brooks
# County 23 of 254
#
# Brown
# County 24 of 254
#
# Burleson
# County 25 of 254
#
# Burnet
# County 26 of 254
#
# Caldwell
# County 27 of 254
#
# Calhoun
# County 28 of 254
#
# Callahan
# County 29 of 254
#
# Cameron
# County 30 of 254
#
# Camp
# County 31 of 254
#
# Carson
# County 32 of 254
#
# Cass
# County 33 of 254
#
# Castro
# County 34 of 254
#
# Chambers
# County 35 of 254
#
# Cherokee
# County 36 of 254
#
# Childress
# County 37 of 254
#
# Clay
# County 38 of 254
#
# Cochran
# County 39 of 254
#
# Coke
# County 40 of 254
#
# Coleman
# County 41 of 254
#
# Collin
# County 42 of 254
#
# Collingsworth
# County 43 of 254
#
# Colorado
# County 44 of 254
#
# Comal
# County 45 of 254
#
# Comanche
# County 46 of 254
#
# Concho
# County 47 of 254
#
# Cooke
# County 48 of 254
#
# Coryell
# County 49 of 254
#
# Cottle
# County 50 of 254
#
# Crane
# County 51 of 254
#
# Crockett
# County 52 of 254
#
# Crosby
# County 53 of 254
#
# Culberson
# County 54 of 254
#
# Dallam
# County 55 of 254
#
# Dallas
# County 56 of 254
# Reading files...
# ../topdown_parsers.py:284: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df["tract"] = df["tract"].str.split(expand=True)[2].str.replace(".", "").str.pad(6, "right", "0")
# Completed reading files
#
# Dawson
# County 57 of 254
#
# DeWitt
# County 58 of 254
#
# Deaf Smith
# County 59 of 254
#
# Delta
# County 60 of 254
#
# Denton
# County 61 of 254
#
# Dickens
# County 62 of 254
#
# Dimmit
# County 63 of 254
#
# Donley
# County 64 of 254
#
# Duval
# County 65 of 254
#
# Eastland
# County 66 of 254
#
# Ector
# County 67 of 254
#
# Edwards
# County 68 of 254
#
# El Paso
# County 69 of 254
#
# Ellis
# County 70 of 254
#
# Erath
# County 71 of 254
#
# Falls
# County 72 of 254
#
# Fannin
# County 73 of 254
#
# Fayette
# County 74 of 254
#
# Fisher
# County 75 of 254
#
# Floyd
# County 76 of 254
#
# Foard
# County 77 of 254
#
# Fort Bend
# County 78 of 254
#
# Franklin
# County 79 of 254
#
# Freestone
# County 80 of 254
#
# Frio
# County 81 of 254
#
# Gaines
# County 82 of 254
#
# Galveston
# County 83 of 254
#
# Garza
# County 84 of 254
#
# Gillespie
# County 85 of 254
#
# Glasscock
# County 86 of 254
#
# Goliad
# County 87 of 254
#
# Gonzales
# County 88 of 254
#
# Gray
# County 89 of 254
#
# Grayson
# County 90 of 254
#
# Gregg
# County 91 of 254
#
# Grimes
# County 92 of 254
#
# Guadalupe
# County 93 of 254
#
# Hale
# County 94 of 254
#
# Hall
# County 95 of 254
#
# Hamilton
# County 96 of 254
#
# Hansford
# County 97 of 254
#
# Hardeman
# County 98 of 254
#
# Hardin
# County 99 of 254
#
# Harris
# County 100 of 254
#
# Harrison
# County 101 of 254
#
# Hartley
# County 102 of 254
#
# Haskell
# County 103 of 254
#
# Hays
# County 104 of 254
#
# Hemphill
# County 105 of 254
#
# Henderson
# County 106 of 254
#
# Hidalgo
# County 107 of 254
#
# Hill
# County 108 of 254
#
# Hockley
# County 109 of 254
#
# Hood
# County 110 of 254
#
# Hopkins
# County 111 of 254
#
# Houston
# County 112 of 254
#
# Howard
# County 113 of 254
#
# Hudspeth
# County 114 of 254
#
# Hunt
# County 115 of 254
#
# Hutchinson
# County 116 of 254
#
# Irion
# County 117 of 254
#
# Jack
# County 118 of 254
#
# Jackson
# County 119 of 254
#
# Jasper
# County 120 of 254
#
# Jeff Davis
# County 121 of 254
#
# Jefferson
# County 122 of 254
#
# Jim Hogg
# County 123 of 254
#
# Jim Wells
# County 124 of 254
#
# Johnson
# County 125 of 254
#
# Jones
# County 126 of 254
#
# Karnes
# County 127 of 254
#
# Kaufman
# County 128 of 254
#
# Kendall
# County 129 of 254
#
# Kenedy
# County 130 of 254
#
# Kent
# County 131 of 254
#
# Kerr
# County 132 of 254
#
# Kimble
# County 133 of 254
#
# King
# County 134 of 254
#
# Kinney
# County 135 of 254
#
# Kleberg
# County 136 of 254
#
# Knox
# County 137 of 254
#
# La Salle
# County 138 of 254
#
# Lamar
# County 139 of 254
#
# Lamb
# County 140 of 254
#
# Lampasas
# County 141 of 254
#
# Lavaca
# County 142 of 254
#
# Lee
# County 143 of 254
#
# Leon
# County 144 of 254
#
# Liberty
# County 145 of 254
#
# Limestone
# County 146 of 254
#
# Lipscomb
# County 147 of 254
#
# Live Oak
# County 148 of 254
#
# Llano
# County 149 of 254
#
# Loving
# County 150 of 254
#
# Lubbock
# County 151 of 254
#
# Lynn
# County 152 of 254
#
# Madison
# County 153 of 254
#
# Marion
# County 154 of 254
#
# Martin
# County 155 of 254
#
# Mason
# County 156 of 254
#
# Matagorda
# County 157 of 254
#
# Maverick
# County 158 of 254
#
# McCulloch
# County 159 of 254
#
# McLennan
# County 160 of 254
#
# McMullen
# County 161 of 254
#
# Medina
# County 162 of 254
#
# Menard
# County 163 of 254
#
# Midland
# County 164 of 254
#
# Milam
# County 165 of 254
#
# Mills
# County 166 of 254
#
# Mitchell
# County 167 of 254
#
# Montague
# County 168 of 254
#
# Montgomery
# County 169 of 254
#
# Moore
# County 170 of 254
#
# Morris
# County 171 of 254
#
# Motley
# County 172 of 254
#
# Nacogdoches
# County 173 of 254
#
# Navarro
# County 174 of 254
#
# Newton
# County 175 of 254
#
# Nolan
# County 176 of 254
#
# Nueces
# County 177 of 254
#
# Ochiltree
# County 178 of 254
#
# Oldham
# County 179 of 254
#
# Orange
# County 180 of 254
#
# Palo Pinto
# County 181 of 254
#
# Panola
# County 182 of 254
#
# Parker
# County 183 of 254
#
# Parmer
# County 184 of 254
#
# Pecos
# County 185 of 254
#
# Polk
# County 186 of 254
#
# Potter
# County 187 of 254
#
# Presidio
# County 188 of 254
#
# Rains
# County 189 of 254
#
# Randall
# County 190 of 254
#
# Reagan
# County 191 of 254
#
# Real
# County 192 of 254
#
# Red River
# County 193 of 254
#
# Reeves
# County 194 of 254
#
# Refugio
# County 195 of 254
#
# Roberts
# County 196 of 254
#
# Robertson
# County 197 of 254
#
# Rockwall
# County 198 of 254
#
# Runnels
# County 199 of 254
#
# Rusk
# County 200 of 254
#
# Sabine
# County 201 of 254
#
# San Augustine
# County 202 of 254
#
# San Jacinto
# County 203 of 254
#
# San Patricio
# County 204 of 254
#
# San Saba
# County 205 of 254
#
# Schleicher
# County 206 of 254
#
# Scurry
# County 207 of 254
#
# Shackelford
# County 208 of 254
#
# Shelby
# County 209 of 254
#
# Sherman
# County 210 of 254
#
# Smith
# County 211 of 254
#
# Somervell
# County 212 of 254
#
# Starr
# County 213 of 254
#
# Stephens
# County 214 of 254
#
# Sterling
# County 215 of 254
#
# Stonewall
# County 216 of 254
#
# Sutton
# County 217 of 254
#
# Swisher
# County 218 of 254
#
# Tarrant
# County 219 of 254
#
# Taylor
# County 220 of 254
#
# Terrell
# County 221 of 254
#
# Terry
# County 222 of 254
#
# Throckmorton
# County 223 of 254
#
# Titus
# County 224 of 254
#
# Tom Green
# County 225 of 254
#
# Travis
# County 226 of 254
#
# Trinity
# County 227 of 254
#
# Tyler
# County 228 of 254
#
# Upshur
# County 229 of 254
#
# Upton
# County 230 of 254
#
# Uvalde
# County 231 of 254
#
# Val Verde
# County 232 of 254
#
# Van Zandt
# County 233 of 254
#
# Victoria
# County 234 of 254
#
# Walker
# County 235 of 254
#
# Waller
# County 236 of 254
#
# Ward
# County 237 of 254
#
# Washington
# County 238 of 254
#
# Webb
# County 239 of 254
#
# Wharton
# County 240 of 254
#
# Wheeler
# County 241 of 254
#
# Wichita
# County 242 of 254
#
# Wilbarger
# County 243 of 254
#
# Willacy
# County 244 of 254
#
# Williamson
# County 245 of 254
#
# Wilson
# County 246 of 254
#
# Winkler
# County 247 of 254
#
# Wise
# County 248 of 254
#
# Wood
# County 249 of 254
#
# Yoakum
# County 250 of 254
#
# Young
# County 251 of 254
#
# Zapata
# County 252 of 254
#
# Zavala
# County 253 of 254

# %%
h_lines, p_lines = num_lines_by_type("../../../five_counties.dat")

# %%
h_lines, p_lines

# %%
df = read_and_process_reconstructed_csvs("./new_Reconstructed/Texas_Bell County")
df
