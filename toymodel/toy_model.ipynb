# %%
import math
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from toymodel import GeoUnit, ToyModel

# %%
hierarchy = [("Country", 1, 810.), 
             ("State", 3, 270.), 
             ("County", 3, 90.), 
             ("Dist", 3, 30.)]

eps_budget = 0.4998 # I picked a random number from one of Peter's runs
eps_splits = [0, 0.33, 0.33, 0.34] 

toy = ToyModel(hierarchy, eps_budget, eps_splits)
toy.show()
# Out:
# Country
# ├── CountryState1
# │   ├── CountryState1County1
# │   │   ├── CountryState1County1Dist1
# │   │   ├── CountryState1County1Dist2
# │   │   └── CountryState1County1Dist3
# │   ├── CountryState1County2
# │   │   ├── CountryState1County2Dist1
# │   │   ├── CountryState1County2Dist2
# │   │   └── CountryState1County2Dist3
# │   └── CountryState1County3
# │       ├── CountryState1County3Dist1
# │       ├── CountryState1County3Dist2
# │       └── CountryState1County3Dist3
# ├── CountryState2
# │   ├── CountryState2County1
# │   │   ├── CountryState2County1Dist1
# │   │   ├── CountryState2County1Dist2
# │   │   └── CountryState2County1Dist3
# │   ├── CountryState2County2
# │   │   ├── CountryState2County2Dist1
# │   │   ├── CountryState2County2Dist2
# │   │   └── CountryState2County2Dist3
# │   └── CountryState2County3
# │       ├── CountryState2County3Dist1
# │       ├── CountryState2County3Dist2
# │       └── CountryState2County3Dist3
# └── CountryState3
#     ├── CountryState3County1
#     │   ├── CountryState3County1Dist1
#     │   ├── CountryState3County1Dist2
#     │   └── CountryState3County1Dist3
#     ├── CountryState3County2
#     │   ├── CountryState3County2Dist1
#     │   ├── CountryState3County2Dist2
#     │   └── CountryState3County2Dist3
#     └── CountryState3County3
#         ├── CountryState3County3Dist1
#         ├── CountryState3County3Dist2
#         └── CountryState3County3Dist3

# %%
# This is where everything from Proposition 1 happens.
toy.noise_and_adjust()

# %%
# How to look at the node's attributes
toy.get_node("CountryState3").data.__dict__
# Out:
# {'name': 'CountryState3',
#  'unnoised_pop': 270.0,
#  'parent': 'Country',
#  'identifier': 'CountryState3',
#  'level': 1,
#  'noised_pop': 260.4005955451388,
#  'noise': -9.599404454861183,
#  'noise_type': 'laplacian',
#  'adjusted_pop': 261.8316814438961,
#  'error': -8.168318556103884}

# %%
# A demonstration of Proposition 1, calculated for CountryState1
branching = 3
exp_1 = toy.get_node("CountryState1").data.noise
exp_2 = ( toy.get_node("CountryState1").data.noise \
        + toy.get_node("CountryState2").data.noise \
        + toy.get_node("CountryState3").data.noise ) / branching
exp_3 = toy.get_node("Country").data.error / branching

math.isclose(exp_1 - exp_2 + exp_3,
             toy.get_node("CountryState1").data.error,
             abs_tol=0.00001)
# Out:
# True

# %%
# 6 -level Trees
hierarchy = [("Country", 1, 900000.), 
             ("State", 3, 300000.), 
             ("County", 3, 100000.), 
             ("Tract", 10, 10000.),
             ("BlockGroup", 10, 1000.),
             ("Block", 10, 100.)]

eps_budget = 0.4998 # I picked a random number from one of Peter's runs
eps_splits = [0, 0, 0.25, 0.25, 0.25, 0.25] 

toy = ToyModel(hierarchy, eps_budget, eps_splits)
toy.noise_and_adjust()
toy.show()
# Out:
# Country
# ├── CountryState1
# │   ├── CountryState1County1
# │   │   ├── CountryState1County1Tract1
# │   │   │   ├── CountryState1County1Tract1BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract1BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block10
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block2
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block3
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block4
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block5
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block6
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block7
# │   │   │   │   ├── CountryState1County1Tract1BlockGroup8Block8
# │   │   │   │   └── CountryState1County1Tract1BlockGroup8Block9
# │   │   │   └── CountryState1County1Tract1BlockGroup9
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block1
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block10
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block2
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block3
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block4
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block5
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block6
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block7
# │   │   │       ├── CountryState1County1Tract1BlockGroup9Block8
# │   │   │       └── CountryState1County1Tract1BlockGroup9Block9
# │   │   ├── CountryState1County1Tract10
# │   │   │   ├── CountryState1County1Tract10BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract10BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block10
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block2
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block3
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block4
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block5
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block6
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block7
# │   │   │   │   ├── CountryState1County1Tract10BlockGroup8Block8
# │   │   │   │   └── CountryState1County1Tract10BlockGroup8Block9
# │   │   │   └── CountryState1County1Tract10BlockGroup9
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block1
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block10
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block2
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block3
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block4
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block5
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block6
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block7
# │   │   │       ├── CountryState1County1Tract10BlockGroup9Block8
# │   │   │       └── CountryState1County1Tract10BlockGroup9Block9
# │   │   ├── CountryState1County1Tract2
# │   │   │   ├── CountryState1County1Tract2BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract2BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block10
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block2
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block3
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block4
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block5
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block6
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block7
# │   │   │   │   ├── CountryState1County1Tract2BlockGroup8Block8
# │   │   │   │   └── CountryState1County1Tract2BlockGroup8Block9
# │   │   │   └── CountryState1County1Tract2BlockGroup9
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block1
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block10
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block2
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block3
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block4
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block5
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block6
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block7
# │   │   │       ├── CountryState1County1Tract2BlockGroup9Block8
# │   │   │       └── CountryState1County1Tract2BlockGroup9Block9
# │   │   ├── CountryState1County1Tract3
# │   │   │   ├── CountryState1County1Tract3BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract3BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block10
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block2
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block3
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block4
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block5
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block6
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block7
# │   │   │   │   ├── CountryState1County1Tract3BlockGroup8Block8
# │   │   │   │   └── CountryState1County1Tract3BlockGroup8Block9
# │   │   │   └── CountryState1County1Tract3BlockGroup9
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block1
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block10
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block2
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block3
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block4
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block5
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block6
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block7
# │   │   │       ├── CountryState1County1Tract3BlockGroup9Block8
# │   │   │       └── CountryState1County1Tract3BlockGroup9Block9
# │   │   ├── CountryState1County1Tract4
# │   │   │   ├── CountryState1County1Tract4BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract4BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block10
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block2
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block3
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block4
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block5
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block6
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block7
# │   │   │   │   ├── CountryState1County1Tract4BlockGroup8Block8
# │   │   │   │   └── CountryState1County1Tract4BlockGroup8Block9
# │   │   │   └── CountryState1County1Tract4BlockGroup9
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block1
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block10
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block2
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block3
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block4
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block5
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block6
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block7
# │   │   │       ├── CountryState1County1Tract4BlockGroup9Block8
# │   │   │       └── CountryState1County1Tract4BlockGroup9Block9
# │   │   ├── CountryState1County1Tract5
# │   │   │   ├── CountryState1County1Tract5BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract5BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block10
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block2
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block3
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block4
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block5
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block6
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block7
# │   │   │   │   ├── CountryState1County1Tract5BlockGroup8Block8
# │   │   │   │   └── CountryState1County1Tract5BlockGroup8Block9
# │   │   │   └── CountryState1County1Tract5BlockGroup9
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block1
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block10
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block2
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block3
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block4
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block5
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block6
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block7
# │   │   │       ├── CountryState1County1Tract5BlockGroup9Block8
# │   │   │       └── CountryState1County1Tract5BlockGroup9Block9
# │   │   ├── CountryState1County1Tract6
# │   │   │   ├── CountryState1County1Tract6BlockGroup1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup1Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup1Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup10Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup10Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup2Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup2Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup3Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup3Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup4Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup4Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup5Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup5Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup6Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup6Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block10
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block2
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block3
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block4
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block5
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block6
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block7
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup7Block8
# │   │   │   │   └── CountryState1County1Tract6BlockGroup7Block9
# │   │   │   ├── CountryState1County1Tract6BlockGroup8
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup8Block1
# │   │   │   │   ├── CountryState1County1Tract6BlockGroup8Block10
# ...
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block10
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block2
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block3
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block4
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block5
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block6
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block7
#         │   │   ├── CountryState3County3Tract7BlockGroup7Block8
#         │   │   └── CountryState3County3Tract7BlockGroup7Block9
#         │   ├── CountryState3County3Tract7BlockGroup8
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block1
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block10
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block2
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block3
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block4
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block5
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block6
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block7
#         │   │   ├── CountryState3County3Tract7BlockGroup8Block8
#         │   │   └── CountryState3County3Tract7BlockGroup8Block9
#         │   └── CountryState3County3Tract7BlockGroup9
#         │       ├── CountryState3County3Tract7BlockGroup9Block1
#         │       ├── CountryState3County3Tract7BlockGroup9Block10
#         │       ├── CountryState3County3Tract7BlockGroup9Block2
#         │       ├── CountryState3County3Tract7BlockGroup9Block3
#         │       ├── CountryState3County3Tract7BlockGroup9Block4
#         │       ├── CountryState3County3Tract7BlockGroup9Block5
#         │       ├── CountryState3County3Tract7BlockGroup9Block6
#         │       ├── CountryState3County3Tract7BlockGroup9Block7
#         │       ├── CountryState3County3Tract7BlockGroup9Block8
#         │       └── CountryState3County3Tract7BlockGroup9Block9
#         ├── CountryState3County3Tract8
#         │   ├── CountryState3County3Tract8BlockGroup1
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup1Block8
#         │   │   └── CountryState3County3Tract8BlockGroup1Block9
#         │   ├── CountryState3County3Tract8BlockGroup10
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup10Block8
#         │   │   └── CountryState3County3Tract8BlockGroup10Block9
#         │   ├── CountryState3County3Tract8BlockGroup2
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup2Block8
#         │   │   └── CountryState3County3Tract8BlockGroup2Block9
#         │   ├── CountryState3County3Tract8BlockGroup3
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup3Block8
#         │   │   └── CountryState3County3Tract8BlockGroup3Block9
#         │   ├── CountryState3County3Tract8BlockGroup4
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup4Block8
#         │   │   └── CountryState3County3Tract8BlockGroup4Block9
#         │   ├── CountryState3County3Tract8BlockGroup5
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup5Block8
#         │   │   └── CountryState3County3Tract8BlockGroup5Block9
#         │   ├── CountryState3County3Tract8BlockGroup6
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup6Block8
#         │   │   └── CountryState3County3Tract8BlockGroup6Block9
#         │   ├── CountryState3County3Tract8BlockGroup7
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup7Block8
#         │   │   └── CountryState3County3Tract8BlockGroup7Block9
#         │   ├── CountryState3County3Tract8BlockGroup8
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block1
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block10
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block2
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block3
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block4
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block5
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block6
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block7
#         │   │   ├── CountryState3County3Tract8BlockGroup8Block8
#         │   │   └── CountryState3County3Tract8BlockGroup8Block9
#         │   └── CountryState3County3Tract8BlockGroup9
#         │       ├── CountryState3County3Tract8BlockGroup9Block1
#         │       ├── CountryState3County3Tract8BlockGroup9Block10
#         │       ├── CountryState3County3Tract8BlockGroup9Block2
#         │       ├── CountryState3County3Tract8BlockGroup9Block3
#         │       ├── CountryState3County3Tract8BlockGroup9Block4
#         │       ├── CountryState3County3Tract8BlockGroup9Block5
#         │       ├── CountryState3County3Tract8BlockGroup9Block6
#         │       ├── CountryState3County3Tract8BlockGroup9Block7
#         │       ├── CountryState3County3Tract8BlockGroup9Block8
#         │       └── CountryState3County3Tract8BlockGroup9Block9
#         └── CountryState3County3Tract9
#             ├── CountryState3County3Tract9BlockGroup1
#             │   ├── CountryState3County3Tract9BlockGroup1Block1
#             │   ├── CountryState3County3Tract9BlockGroup1Block10
#             │   ├── CountryState3County3Tract9BlockGroup1Block2
#             │   ├── CountryState3County3Tract9BlockGroup1Block3
#             │   ├── CountryState3County3Tract9BlockGroup1Block4
#             │   ├── CountryState3County3Tract9BlockGroup1Block5
#             │   ├── CountryState3County3Tract9BlockGroup1Block6
#             │   ├── CountryState3County3Tract9BlockGroup1Block7
#             │   ├── CountryState3County3Tract9BlockGroup1Block8
#             │   └── CountryState3County3Tract9BlockGroup1Block9
#             ├── CountryState3County3Tract9BlockGroup10
#             │   ├── CountryState3County3Tract9BlockGroup10Block1
#             │   ├── CountryState3County3Tract9BlockGroup10Block10
#             │   ├── CountryState3County3Tract9BlockGroup10Block2
#             │   ├── CountryState3County3Tract9BlockGroup10Block3
#             │   ├── CountryState3County3Tract9BlockGroup10Block4
#             │   ├── CountryState3County3Tract9BlockGroup10Block5
#             │   ├── CountryState3County3Tract9BlockGroup10Block6
#             │   ├── CountryState3County3Tract9BlockGroup10Block7
#             │   ├── CountryState3County3Tract9BlockGroup10Block8
#             │   └── CountryState3County3Tract9BlockGroup10Block9
#             ├── CountryState3County3Tract9BlockGroup2
#             │   ├── CountryState3County3Tract9BlockGroup2Block1
#             │   ├── CountryState3County3Tract9BlockGroup2Block10
#             │   ├── CountryState3County3Tract9BlockGroup2Block2
#             │   ├── CountryState3County3Tract9BlockGroup2Block3
#             │   ├── CountryState3County3Tract9BlockGroup2Block4
#             │   ├── CountryState3County3Tract9BlockGroup2Block5
#             │   ├── CountryState3County3Tract9BlockGroup2Block6
#             │   ├── CountryState3County3Tract9BlockGroup2Block7
#             │   ├── CountryState3County3Tract9BlockGroup2Block8
#             │   └── CountryState3County3Tract9BlockGroup2Block9
#             ├── CountryState3County3Tract9BlockGroup3
#             │   ├── CountryState3County3Tract9BlockGroup3Block1
#             │   ├── CountryState3County3Tract9BlockGroup3Block10
#             │   ├── CountryState3County3Tract9BlockGroup3Block2
#             │   ├── CountryState3County3Tract9BlockGroup3Block3
#             │   ├── CountryState3County3Tract9BlockGroup3Block4
#             │   ├── CountryState3County3Tract9BlockGroup3Block5
#             │   ├── CountryState3County3Tract9BlockGroup3Block6
#             │   ├── CountryState3County3Tract9BlockGroup3Block7
#             │   ├── CountryState3County3Tract9BlockGroup3Block8
#             │   └── CountryState3County3Tract9BlockGroup3Block9
#             ├── CountryState3County3Tract9BlockGroup4
#             │   ├── CountryState3County3Tract9BlockGroup4Block1
#             │   ├── CountryState3County3Tract9BlockGroup4Block10
#             │   ├── CountryState3County3Tract9BlockGroup4Block2
#             │   ├── CountryState3County3Tract9BlockGroup4Block3
#             │   ├── CountryState3County3Tract9BlockGroup4Block4
#             │   ├── CountryState3County3Tract9BlockGroup4Block5
#             │   ├── CountryState3County3Tract9BlockGroup4Block6
#             │   ├── CountryState3County3Tract9BlockGroup4Block7
#             │   ├── CountryState3County3Tract9BlockGroup4Block8
#             │   └── CountryState3County3Tract9BlockGroup4Block9
#             ├── CountryState3County3Tract9BlockGroup5
#             │   ├── CountryState3County3Tract9BlockGroup5Block1
#             │   ├── CountryState3County3Tract9BlockGroup5Block10
#             │   ├── CountryState3County3Tract9BlockGroup5Block2
#             │   ├── CountryState3County3Tract9BlockGroup5Block3
#             │   ├── CountryState3County3Tract9BlockGroup5Block4
#             │   ├── CountryState3County3Tract9BlockGroup5Block5
#             │   ├── CountryState3County3Tract9BlockGroup5Block6
#             │   ├── CountryState3County3Tract9BlockGroup5Block7
#             │   ├── CountryState3County3Tract9BlockGroup5Block8
#             │   └── CountryState3County3Tract9BlockGroup5Block9
#             ├── CountryState3County3Tract9BlockGroup6
#             │   ├── CountryState3County3Tract9BlockGroup6Block1
#             │   ├── CountryState3County3Tract9BlockGroup6Block10
#             │   ├── CountryState3County3Tract9BlockGroup6Block2
#             │   ├── CountryState3County3Tract9BlockGroup6Block3
#             │   ├── CountryState3County3Tract9BlockGroup6Block4
#             │   ├── CountryState3County3Tract9BlockGroup6Block5
#             │   ├── CountryState3County3Tract9BlockGroup6Block6
#             │   ├── CountryState3County3Tract9BlockGroup6Block7
#             │   ├── CountryState3County3Tract9BlockGroup6Block8
#             │   └── CountryState3County3Tract9BlockGroup6Block9
#             ├── CountryState3County3Tract9BlockGroup7
#             │   ├── CountryState3County3Tract9BlockGroup7Block1
#             │   ├── CountryState3County3Tract9BlockGroup7Block10
#             │   ├── CountryState3County3Tract9BlockGroup7Block2
#             │   ├── CountryState3County3Tract9BlockGroup7Block3
#             │   ├── CountryState3County3Tract9BlockGroup7Block4
#             │   ├── CountryState3County3Tract9BlockGroup7Block5
#             │   ├── CountryState3County3Tract9BlockGroup7Block6
#             │   ├── CountryState3County3Tract9BlockGroup7Block7
#             │   ├── CountryState3County3Tract9BlockGroup7Block8
#             │   └── CountryState3County3Tract9BlockGroup7Block9
#             ├── CountryState3County3Tract9BlockGroup8
#             │   ├── CountryState3County3Tract9BlockGroup8Block1
#             │   ├── CountryState3County3Tract9BlockGroup8Block10
#             │   ├── CountryState3County3Tract9BlockGroup8Block2
#             │   ├── CountryState3County3Tract9BlockGroup8Block3
#             │   ├── CountryState3County3Tract9BlockGroup8Block4
#             │   ├── CountryState3County3Tract9BlockGroup8Block5
#             │   ├── CountryState3County3Tract9BlockGroup8Block6
#             │   ├── CountryState3County3Tract9BlockGroup8Block7
#             │   ├── CountryState3County3Tract9BlockGroup8Block8
#             │   └── CountryState3County3Tract9BlockGroup8Block9
#             └── CountryState3County3Tract9BlockGroup9
#                 ├── CountryState3County3Tract9BlockGroup9Block1
#                 ├── CountryState3County3Tract9BlockGroup9Block10
#                 ├── CountryState3County3Tract9BlockGroup9Block2
#                 ├── CountryState3County3Tract9BlockGroup9Block3
#                 ├── CountryState3County3Tract9BlockGroup9Block4
#                 ├── CountryState3County3Tract9BlockGroup9Block5
#                 ├── CountryState3County3Tract9BlockGroup9Block6
#                 ├── CountryState3County3Tract9BlockGroup9Block7
#                 ├── CountryState3County3Tract9BlockGroup9Block8
#                 └── CountryState3County3Tract9BlockGroup9Block9

# %%
# First, a sanity check that the equation at the end of Prop 4 works
# We will do this check on CountryState1County1Tract1
p = 0.5
dist_blocks = []
other_blocks = []
tract = toy.get_node("CountryState1County1Tract1")
block_groups = toy.children(tract.identifier)

def set_diff(a, b):
    return list(set(a).difference(set(b)))

for bg in block_groups:
    blocks = toy.children(bg.identifier)
    chosen_blocks = np.random.choice(blocks, int(p*10), replace=False)
    
    dist_blocks.extend(chosen_blocks)
    other_blocks.extend(set_diff(blocks, chosen_blocks))

dist_blk_noises = [blk.data.noise for blk in dist_blocks]
other_blk_noises = [blk.data.noise for blk in other_blocks]
blk_errors = [blk.data.error for blk in dist_blocks]

math.isclose((1-p) * sum(dist_blk_noises) - p * sum(other_blk_noises) + p * tract.data.error,
             sum(blk_errors),
             abs_tol = 0.000001)
# Out:
# True

# %%
# get blk errors for p from 0 to 1
def get_district_errors_at_p(p, tract_name):
    dist_blocks = []
    other_blocks = []
    tract = toy.get_node(tract_name)
    block_groups = toy.children(tract.identifier)

    for bg in block_groups:
        blocks = toy.children(bg.identifier)
        chosen_blocks = np.random.choice(blocks, int(p*10), replace=False)
        dist_blocks.extend(chosen_blocks)

    raw_errors = [blk.data.error for blk in dist_blocks]
    abs_errors = [abs(err) for err in raw_errors]
    
    return sum(raw_errors), sum(abs_errors)

# %%
raw_error_sums = []
abs_error_sums = []
ps = np.linspace(0,1,11)
for p in ps:
    raw_err, abs_err = get_district_errors_at_p(p, "CountryState1County1Tract1")
    raw_error_sums.append(raw_err)
    abs_error_sums.append(abs_err)

# %%
plt.plot(ps, raw_error_sums)

# %%
# we are probably more interested in the absolute value of the errors than the actual sum of errors
plt.plot(ps, abs_error_sums)
