# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sample = np.random.laplace(size=(100000))
plt.hist(sample, bins=1000)
plt.show()

# %%
sums = list()
for i in range(10000):
    sample = np.random.laplace(size=(100))
    sums.append(sum(sample))
plt.hist(sums, bins=200)
print("Variance ", np.var(sums))
# Out:
# Variance  200.884520180708

# %%
sample = np.random.laplace(size=(100))
print("Variance ", np.var(sample))
print("Mean ", np.mean(sample))

# %%
# how is (sum of ten indep draws)/10 shaped differently from 1 draw?
